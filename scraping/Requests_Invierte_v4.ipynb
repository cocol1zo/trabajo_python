# %%
import pandas as pd
import requests 
import numpy as py

# %%
url = 'http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428470'
html = requests.get(url).content
df_list = pd.read_html(html)
df = df_list[-2]
df
# Out:
#   Según el Formato N° 02 de Formulación y Evaluación  \
#                                    Tipo de inversión
# 0                                AMPLIACIÓN MARGINAL
# 1                                AMPLIACIÓN MARGINAL
# 2                                       SUBTOTAL: S/
# 3                             EXPEDIENTE TÉCNICO: S/
# 4                                    SUPERVISIÓN: S/
# 5                        COSTO TOTAL ACTUALIZADO: S/
#
#                                                              \
#                     Naturaleza    Tipo de factor productivo
# 0                 REMODELACION              INFRAESTRUCTURA
# 1                  ADQUISICION                 EQUIPAMIENTO
# 2                 SUBTOTAL: S/                 SUBTOTAL: S/
# 3       EXPEDIENTE TÉCNICO: S/       EXPEDIENTE TÉCNICO: S/
# 4              SUPERVISIÓN: S/              SUPERVISIÓN: S/
# 5  COSTO TOTAL ACTUALIZADO: S/  COSTO TOTAL ACTUALIZADO: S/
#
#                                                    \
#                                            Activo
# 0               AMBIENTE U OFICINA ADMINISTRATIVA
# 1  PAQUETES DE MUEBLES PARA PERSONAL NO MODULARES
# 2                                    SUBTOTAL: S/
# 3                          EXPEDIENTE TÉCNICO: S/
# 4                                 SUPERVISIÓN: S/
# 5                     COSTO TOTAL ACTUALIZADO: S/
#
#   Según expediente técnico o documentos equivalentes aprobados  \
#        Costo de inversión modificado (a precios de mercado) S/
# 0                                          721961.85
# 1                                           69450.24
# 2                                          791412.09
# 3                                           53151.00
# 4                                           91477.98
# 5                                          936041.07
#
#                                                                              \
#                     Modalidad de ejecución Fecha de inicio Fecha de término
# 0  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 1  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 2                                      NaN             NaN              NaN
# 3                                      NaN             NaN              NaN
# 4                                      NaN             NaN              NaN
# 5                                      NaN             NaN              NaN
#
#                                                         \
#   Fecha de entrega del activo al responsable de su OYM
# 0                                         13/12/2019
# 1                                         13/12/2019
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#
#                                                  UEI
# 0  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 1  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
#len(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 10 columns):
# (Según el Formato N° 02 de Formulación y Evaluación, Tipo de inversión)                                                    6 non-null object
# (Según el Formato N° 02 de Formulación y Evaluación, Naturaleza)                                                           6 non-null object
# (Según el Formato N° 02 de Formulación y Evaluación, Tipo de factor productivo)                                            6 non-null object
# (Según el Formato N° 02 de Formulación y Evaluación, Activo)                                                               6 non-null object
# (Según expediente técnico o documentos equivalentes aprobados, Costo de inversión modificado (a precios de mercado) S/)    6 non-null float64
# (Según expediente técnico o documentos equivalentes aprobados, Modalidad de ejecución)                                     2 non-null object
# (Según expediente técnico o documentos equivalentes aprobados, Fecha de inicio)                                            2 non-null object
# (Según expediente técnico o documentos equivalentes aprobados, Fecha de término)                                           2 non-null object
# (Según expediente técnico o documentos equivalentes aprobados, Fecha de entrega del activo al responsable de su OYM)       2 non-null object
# (Según expediente técnico o documentos equivalentes aprobados, UEI)                                                        2 non-null object
# dtypes: float64(1), object(9)
# memory usage: 560.0+ bytes

# %%
df = pd.DataFrame(df)

# %%
#df.columns = df.columns.droplevel()

# %%
df
# Out:
#   Según el Formato N° 02 de Formulación y Evaluación  \
#                                    Tipo de inversión
# 0                                AMPLIACIÓN MARGINAL
# 1                                AMPLIACIÓN MARGINAL
# 2                                       SUBTOTAL: S/
# 3                             EXPEDIENTE TÉCNICO: S/
# 4                                    SUPERVISIÓN: S/
# 5                        COSTO TOTAL ACTUALIZADO: S/
#
#                                                              \
#                     Naturaleza    Tipo de factor productivo
# 0                 REMODELACION              INFRAESTRUCTURA
# 1                  ADQUISICION                 EQUIPAMIENTO
# 2                 SUBTOTAL: S/                 SUBTOTAL: S/
# 3       EXPEDIENTE TÉCNICO: S/       EXPEDIENTE TÉCNICO: S/
# 4              SUPERVISIÓN: S/              SUPERVISIÓN: S/
# 5  COSTO TOTAL ACTUALIZADO: S/  COSTO TOTAL ACTUALIZADO: S/
#
#                                                    \
#                                            Activo
# 0               AMBIENTE U OFICINA ADMINISTRATIVA
# 1  PAQUETES DE MUEBLES PARA PERSONAL NO MODULARES
# 2                                    SUBTOTAL: S/
# 3                          EXPEDIENTE TÉCNICO: S/
# 4                                 SUPERVISIÓN: S/
# 5                     COSTO TOTAL ACTUALIZADO: S/
#
#   Según expediente técnico o documentos equivalentes aprobados  \
#        Costo de inversión modificado (a precios de mercado) S/
# 0                                          721961.85
# 1                                           69450.24
# 2                                          791412.09
# 3                                           53151.00
# 4                                           91477.98
# 5                                          936041.07
#
#                                                                              \
#                     Modalidad de ejecución Fecha de inicio Fecha de término
# 0  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 1  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 2                                      NaN             NaN              NaN
# 3                                      NaN             NaN              NaN
# 4                                      NaN             NaN              NaN
# 5                                      NaN             NaN              NaN
#
#                                                         \
#   Fecha de entrega del activo al responsable de su OYM
# 0                                         13/12/2019
# 1                                         13/12/2019
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#
#                                                  UEI
# 0  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 1  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
#dataframes = []
for l in range(2428464,2428469): # Números de 7 dígitos
    url1 = 'http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/' + str(l)
    html1 = requests.get(url1).content
    df_list1 = pd.read_html(html1)
    df1 = df_list1[-2]
    temp_data = pd.DataFrame(df1)
    
    if len(temp_data)>2:print(url1)
    #dataframes.append(temp_data)
    #return pd.concat(dataframes)

#temp_data = pd.DataFrame(df1)
data = pd.concat([df, temp_data], axis = 0)
# Out:
# http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428464
# http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428465
# http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428466
# http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428467
# http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428468

# %%
data
# Out:
#   Según el Formato N° 02 de Formulación y Evaluación  \
#                                    Tipo de inversión
# 0                                AMPLIACIÓN MARGINAL
# 1                                AMPLIACIÓN MARGINAL
# 2                                       SUBTOTAL: S/
# 3                             EXPEDIENTE TÉCNICO: S/
# 4                                    SUPERVISIÓN: S/
# 5                        COSTO TOTAL ACTUALIZADO: S/
# 0                                AMPLIACIÓN MARGINAL
# 1                                AMPLIACIÓN MARGINAL
# 2                                       SUBTOTAL: S/
# 3                             EXPEDIENTE TÉCNICO: S/
# 4                                    SUPERVISIÓN: S/
# 5                        COSTO TOTAL ACTUALIZADO: S/
#
#                                                              \
#                     Naturaleza    Tipo de factor productivo
# 0                 REMODELACION              INFRAESTRUCTURA
# 1                  ADQUISICION                 EQUIPAMIENTO
# 2                 SUBTOTAL: S/                 SUBTOTAL: S/
# 3       EXPEDIENTE TÉCNICO: S/       EXPEDIENTE TÉCNICO: S/
# 4              SUPERVISIÓN: S/              SUPERVISIÓN: S/
# 5  COSTO TOTAL ACTUALIZADO: S/  COSTO TOTAL ACTUALIZADO: S/
# 0                 REMODELACION              INFRAESTRUCTURA
# 1                  ADQUISICION                 EQUIPAMIENTO
# 2                 SUBTOTAL: S/                 SUBTOTAL: S/
# 3       EXPEDIENTE TÉCNICO: S/       EXPEDIENTE TÉCNICO: S/
# 4              SUPERVISIÓN: S/              SUPERVISIÓN: S/
# 5  COSTO TOTAL ACTUALIZADO: S/  COSTO TOTAL ACTUALIZADO: S/
#
#                                                    \
#                                            Activo
# 0               AMBIENTE U OFICINA ADMINISTRATIVA
# 1  PAQUETES DE MUEBLES PARA PERSONAL NO MODULARES
# 2                                    SUBTOTAL: S/
# 3                          EXPEDIENTE TÉCNICO: S/
# 4                                 SUPERVISIÓN: S/
# 5                     COSTO TOTAL ACTUALIZADO: S/
# 0                                     EDIFICACION
# 1  PAQUETES DE MUEBLES PARA PERSONAL NO MODULARES
# 2                                    SUBTOTAL: S/
# 3                          EXPEDIENTE TÉCNICO: S/
# 4                                 SUPERVISIÓN: S/
# 5                     COSTO TOTAL ACTUALIZADO: S/
#
#   Según expediente técnico o documentos equivalentes aprobados  \
#        Costo de inversión modificado (a precios de mercado) S/
# 0                                          721961.85
# 1                                           69450.24
# 2                                          791412.09
# 3                                           53151.00
# 4                                           91477.98
# 5                                          936041.07
# 0                                          512559.90
# 1                                           35464.37
# 2                                          548024.27
# 3                                           50856.00
# 4                                           97180.17
# 5                                          696060.44
#
#                                                                              \
#                     Modalidad de ejecución Fecha de inicio Fecha de término
# 0  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 1  ADMINISTRACION INDIRECTA - POR CONTRATA      14/06/2019       14/10/2019
# 2                                      NaN             NaN              NaN
# 3                                      NaN             NaN              NaN
# 4                                      NaN             NaN              NaN
# 5                                      NaN             NaN              NaN
# 0  ADMINISTRACION INDIRECTA - POR CONTRATA      01/07/2019       14/10/2019
# 1  ADMINISTRACION INDIRECTA - POR CONTRATA      01/07/2019       14/10/2019
# 2                                      NaN             NaN              NaN
# 3                                      NaN             NaN              NaN
# 4                                      NaN             NaN              NaN
# 5                                      NaN             NaN              NaN
#
#                                                         \
#   Fecha de entrega del activo al responsable de su OYM
# 0                                         13/12/2019
# 1                                         13/12/2019
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 0                                         13/12/2019
# 1                                         13/12/2019
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#
#                                                  UEI
# 0  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 1  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 0  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 1  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
len(data)
# Out:
# 12

# %%
data.tail()
# Out:
#   Según el Formato N° 02 de Formulación y Evaluación  \
#                                    Tipo de inversión
# 1                                AMPLIACIÓN MARGINAL
# 2                                       SUBTOTAL: S/
# 3                             EXPEDIENTE TÉCNICO: S/
# 4                                    SUPERVISIÓN: S/
# 5                        COSTO TOTAL ACTUALIZADO: S/
#
#                                                              \
#                     Naturaleza    Tipo de factor productivo
# 1                  ADQUISICION                 EQUIPAMIENTO
# 2                 SUBTOTAL: S/                 SUBTOTAL: S/
# 3       EXPEDIENTE TÉCNICO: S/       EXPEDIENTE TÉCNICO: S/
# 4              SUPERVISIÓN: S/              SUPERVISIÓN: S/
# 5  COSTO TOTAL ACTUALIZADO: S/  COSTO TOTAL ACTUALIZADO: S/
#
#                                                    \
#                                            Activo
# 1  PAQUETES DE MUEBLES PARA PERSONAL NO MODULARES
# 2                                    SUBTOTAL: S/
# 3                          EXPEDIENTE TÉCNICO: S/
# 4                                 SUPERVISIÓN: S/
# 5                     COSTO TOTAL ACTUALIZADO: S/
#
#   Según expediente técnico o documentos equivalentes aprobados  \
#        Costo de inversión modificado (a precios de mercado) S/
# 1                                           35464.37
# 2                                          548024.27
# 3                                           50856.00
# 4                                           97180.17
# 5                                          696060.44
#
#                                                                              \
#                     Modalidad de ejecución Fecha de inicio Fecha de término
# 1  ADMINISTRACION INDIRECTA - POR CONTRATA      01/07/2019       14/10/2019
# 2                                      NaN             NaN              NaN
# 3                                      NaN             NaN              NaN
# 4                                      NaN             NaN              NaN
# 5                                      NaN             NaN              NaN
#
#                                                         \
#   Fecha de entrega del activo al responsable de su OYM
# 1                                         13/12/2019
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#
#                                                  UEI
# 1  OFICINA DE OBRAS DE LA OFICINA GENERAL DE INFR...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN

# %%
data = pd.DataFrame(df)

# %%
data.head()

# %% [markdown]
# # NUEVA VERSION DE OPEN SOURCE

# %%
url2 = 'http://ofi5.mef.gob.pe/invierte/ejecucion/verFichaEjecucion/2428470'

# %%
html2 = requests.get(url2).content

# %%
data1 = pd.read_html(url2)

# %%
# tabla 1 = codigo de inversiones
data1[0]

# %%
# tabla 2 = A1. Datos de la fase de formulación y Evaluación
data1[1]

# %%
# tabla 3 = A2. Articulación con el Programa Multianual de Inversiones (PMI)
data1[2]

# %%
# tabla 4 = A3. Institucionalidad
data1[3].rename(columns={"Unnamed: 0":"Sigla"})

# %%
# tabla 5 = B41 Metas, costos y plazos
data1f = data1[4].rename(columns={"Unnamed: 7_level_1":"Fecha"}) .fillna('0')

# %%
data1f.head()

# %% [markdown]
# # Pendiente
# ### separar la columna "Expediente técnico o documento equivalente" con la fecha

# %%
# tabla 6 = B42 Programación de la ejecución de las inversiones
data_c = data1[5].fillna(0) .rename(columns ={"Costo de inversión modificado (a precios de mercado) S/" : "monto","Fecha de entrega del activo al responsable de su OYM" : "Fecha de entrega del activo"})

# %% [markdown]
# ### Elimina columna con multi-index - doble columna concatenada

# %%
data_c.columns = data_c.columns.droplevel()

# %%
data_c

# %% [markdown]
# #### data1[5].drop(["Según el Formato N° 02 de Formulación y Evaluación","Según expediente técnico o documentos equivalentes aprobados"], axis=1)

# %%
# tabla 7 = 5 Costos de inversión y programación de la ejecución del proyecto de inversión
data1[6].fillna(0)

# %%
data_compon = pd.DataFrame(data_c)

# %%
data_compon

# %% [markdown]
# # itera todas las columnas - nombres

# %%
for col in df2.columns: 
    print(col)

# %% [markdown]
# ### Crear un subconjunto de datos de la df anterior

# %%
df3.to_csv('df3.csv', index=False)

# %%
df3.pivot_table("rat", rows="comp", cols="tipo")

# %%
#col_escogida = ["A","BCosto de inversión modificado (a precios de mercado) S/"]
col_escogida = ["A","B"]
componente = [col_escogida]
componente
